# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train=pd.read_csv('train.csv')
train.shape
# Out:
# (15890, 465)

# %%
train_b = train.groupby('중분류').mean()
train_b = pd.DataFrame(train_b)
train_b.head()
# Out:
# <ipython-input-4-300441069d07>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   train_b = train.groupby('중분류').mean()
#                          ID  2022-01-01  2022-01-02  2022-01-03  2022-01-04  \
# 중분류
# B002-C002-0001   945.742331   26.188139   12.515337   11.625767   12.071575
# B002-C002-0002  1058.564626    5.870748    4.761905    3.448980    2.993197
# B002-C002-0003   792.609375    4.945312    4.460938    4.554688    5.054688
# B002-C002-0004   813.809524    4.676190    4.066667    2.952381    4.819048
# B002-C002-0005   936.348837   14.093023   10.761628   10.040698   10.546512
#
#                 2022-01-05  2022-01-06  2022-01-07  2022-01-08  2022-01-09  \
# 중분류
# B002-C002-0001   15.282209   17.114519   17.750511   22.635992   34.817996
# ...

# %%
train_b=train_b.drop(['ID'],axis=1)

# %%
df=train_b.T
df.head()
# Out:
# 중분류         B002-C002-0001  B002-C002-0002  B002-C002-0003  B002-C002-0004  \
# 2022-01-01       26.188139        5.870748        4.945312        4.676190
# 2022-01-02       12.515337        4.761905        4.460938        4.066667
# 2022-01-03       11.625767        3.448980        4.554688        2.952381
# 2022-01-04       12.071575        2.993197        5.054688        4.819048
# 2022-01-05       15.282209        4.972789        5.867188        7.371429
#
# 중분류         B002-C002-0005  B002-C002-0006  B002-C002-0007  B002-C002-0008  \
# 2022-01-01       14.093023        3.758065        5.010549             0.0
# 2022-01-02       10.761628        3.241935        4.343882             0.0
# 2022-01-03       10.040698        2.639785        4.331224             0.0
# 2022-01-04       10.546512        2.172043        5.204641             0.0
# 2022-01-05       13.872093        3.021505        6.721519             0.0
#
# 중분류         B002-C002-0009  B002-C002-0010  B002-C002-0011
# ...

# %%
df.tail()
# Out:
# 중분류         B002-C002-0001  B002-C002-0002  B002-C002-0003  B002-C002-0004  \
# 2023-03-31        7.110656        2.129252        3.078125        7.190476
# 2023-04-01        6.219262        2.727891        2.632812        8.466667
# 2023-04-02        5.608607        2.231293        3.835938        9.895238
# 2023-04-03        7.514344        2.435374        4.843750       10.904762
# 2023-04-04       10.104508        2.911565        4.796875       13.542857
#
# 중분류         B002-C002-0005  B002-C002-0006  B002-C002-0007  B002-C002-0008  \
# 2023-03-31        8.186047        3.215054        2.514768        3.679245
# 2023-04-01        6.529070        2.612903        1.945148        2.471698
# 2023-04-02        9.139535        2.182796        1.983122        1.584906
# 2023-04-03       13.296512        2.758065        2.883966        3.358491
# 2023-04-04        9.406977        3.241935        2.921941        4.000000
#
# 중분류         B002-C002-0009  B002-C002-0010  B002-C002-0011
# ...

# %%
index=list(df.index)

# %%
columns_list=list(df.columns)
columns_list
# Out:
# ['B002-C002-0001',
#  'B002-C002-0002',
#  'B002-C002-0003',
#  'B002-C002-0004',
#  'B002-C002-0005',
#  'B002-C002-0006',
#  'B002-C002-0007',
#  'B002-C002-0008',
#  'B002-C002-0009',
#  'B002-C002-0010',
#  'B002-C002-0011']

# %%
df.head()
# Out:
# 중분류         B002-C002-0001  B002-C002-0002  B002-C002-0003  B002-C002-0004  \
# 2022-01-01       26.188139        5.870748        4.945312        4.676190
# 2022-01-02       12.515337        4.761905        4.460938        4.066667
# 2022-01-03       11.625767        3.448980        4.554688        2.952381
# 2022-01-04       12.071575        2.993197        5.054688        4.819048
# 2022-01-05       15.282209        4.972789        5.867188        7.371429
#
# 중분류         B002-C002-0005  B002-C002-0006  B002-C002-0007  B002-C002-0008  \
# 2022-01-01       14.093023        3.758065        5.010549             0.0
# 2022-01-02       10.761628        3.241935        4.343882             0.0
# 2022-01-03       10.040698        2.639785        4.331224             0.0
# 2022-01-04       10.546512        2.172043        5.204641             0.0
# 2022-01-05       13.872093        3.021505        6.721519             0.0
#
# 중분류         B002-C002-0009  B002-C002-0010  B002-C002-0011
# ...

# %%
df['ds']=index

# %%
df.head()
# Out:
# 중분류         B002-C002-0001  B002-C002-0002  B002-C002-0003  B002-C002-0004  \
# 2022-01-01       26.188139        5.870748        4.945312        4.676190
# 2022-01-02       12.515337        4.761905        4.460938        4.066667
# 2022-01-03       11.625767        3.448980        4.554688        2.952381
# 2022-01-04       12.071575        2.993197        5.054688        4.819048
# 2022-01-05       15.282209        4.972789        5.867188        7.371429
#
# 중분류         B002-C002-0005  B002-C002-0006  B002-C002-0007  B002-C002-0008  \
# 2022-01-01       14.093023        3.758065        5.010549             0.0
# 2022-01-02       10.761628        3.241935        4.343882             0.0
# 2022-01-03       10.040698        2.639785        4.331224             0.0
# 2022-01-04       10.546512        2.172043        5.204641             0.0
# 2022-01-05       13.872093        3.021505        6.721519             0.0
#
# ...

# %%
df_1=df.drop(['B002-C001-0002','B002-C001-0003','B002-C001-0004','B002-C001-0005'],axis=1)
df_2=df.drop(['B002-C001-0001','B002-C001-0003','B002-C001-0004','B002-C001-0005'],axis=1)
df_3=df.drop(['B002-C001-0001','B002-C001-0002','B002-C001-0004','B002-C001-0005'],axis=1)
df_4=df.drop(['B002-C001-0001','B002-C001-0002','B002-C001-0003','B002-C001-0005'],axis=1)
df_5=df.drop(['B002-C001-0001','B002-C001-0002','B002-C001-0003','B002-C001-0004'],axis=1)

# %%
df_1=pd.DataFrame(df['B002-C002-0001'],df['ds'])
df_2=pd.DataFrame(df['B002-C002-0002'],df['ds'])
df_3=pd.DataFrame(df['B002-C002-0003'],df['ds'])
df_4=pd.DataFrame(df['B002-C002-0004'],df['ds'])
df_5=pd.DataFrame(df['B002-C002-0005'],df['ds'])
df_6=pd.DataFrame(df['B002-C002-0006'],df['ds'])
df_7=pd.DataFrame(df['B002-C002-0007'],df['ds'])
df_8=pd.DataFrame(df['B002-C002-0008'],df['ds'])
df_9=pd.DataFrame(df['B002-C002-0009'],df['ds'])
df_10=pd.DataFrame(df['B002-C002-0010'],df['ds'])
df_11=pd.DataFrame(df['B002-C002-0011'],df['ds'])

# %%
df_1=df_1.reset_index()
df_2=df_2.reset_index()
df_3=df_3.reset_index()
df_4=df_4.reset_index()
df_5=df_5.reset_index()
df_6=df_6.reset_index()
df_7=df_7.reset_index()
df_8=df_8.reset_index()
df_9=df_9.reset_index()
df_10=df_10.reset_index()
df_11=df_11.reset_index()

# %%
df_1
# Out:
#              ds  B002-C002-0001
# 0    2022-01-01       26.188139
# 1    2022-01-02       12.515337
# 2    2022-01-03       11.625767
# 3    2022-01-04       12.071575
# 4    2022-01-05       15.282209
# ..          ...             ...
# 454  2023-03-31        7.110656
# 455  2023-04-01        6.219262
# 456  2023-04-02        5.608607
# 457  2023-04-03        7.514344
# 458  2023-04-04       10.104508
#
# [459 rows x 2 columns]

# %%
df_1.columns=['ds','y']
df_2.columns=['ds','y']
df_3.columns=['ds','y']
df_4.columns=['ds','y']
df_5.columns=['ds','y']
df_6.columns=['ds','y']
df_7.columns=['ds','y']
df_8.columns=['ds','y']
df_9.columns=['ds','y']
df_10.columns=['ds','y']
df_11.columns=['ds','y']

# %%
from prophet import Prophet

# %%
m_df_1 = Prophet(seasonality_mode = 'multiplicative',
                changepoint_prior_scale=0.1,
                yearly_seasonality=10,
                weekly_seasonality=10,
                daily_seasonality=10)


m_df_2 = Prophet(seasonality_mode = 'multiplicative',
                changepoint_prior_scale=0.1,
                yearly_seasonality=10,
                weekly_seasonality=10,
                daily_seasonality=10)


m_df_3 = Prophet(seasonality_mode = 'multiplicative',
                changepoint_prior_scale=0.1,
                yearly_seasonality=10,
                weekly_seasonality=10,
                daily_seasonality=10)


m_df_4 = Prophet(seasonality_mode = 'multiplicative',
                changepoint_prior_scale=0.1,
                yearly_seasonality=10,
                weekly_seasonality=10,
                daily_seasonality=10)


m_df_5 = Prophet(seasonality_mode = 'multiplicative',
                changepoint_prior_scale=0.1,
                yearly_seasonality=10,
                weekly_seasonality=10,
                daily_seasonality=10)

m_df_6 = Prophet(seasonality_mode = 'multiplicative',
                changepoint_prior_scale=0.1,
                yearly_seasonality=10,
                weekly_seasonality=10,
                daily_seasonality=10)


m_df_7 = Prophet(seasonality_mode = 'multiplicative',
                changepoint_prior_scale=0.1,
                yearly_seasonality=10,
                weekly_seasonality=10,
                daily_seasonality=10)


m_df_8 = Prophet(seasonality_mode = 'multiplicative',
                changepoint_prior_scale=0.1,
                yearly_seasonality=10,
                weekly_seasonality=10,
                daily_seasonality=10)


m_df_9 = Prophet(seasonality_mode = 'multiplicative',
                changepoint_prior_scale=0.1,
                yearly_seasonality=10,
                weekly_seasonality=10,
                daily_seasonality=10)


m_df_10 = Prophet(seasonality_mode = 'multiplicative',
                changepoint_prior_scale=0.1,
                yearly_seasonality=10,
                weekly_seasonality=10,
                daily_seasonality=10)


m_df_11 = Prophet(seasonality_mode = 'multiplicative',
                changepoint_prior_scale=0.1,
                yearly_seasonality=10,
                weekly_seasonality=10,
                daily_seasonality=10)

# %%
m_df_1.fit(df_1)
m_df_2.fit(df_2)
m_df_3.fit(df_3)
m_df_4.fit(df_4)
m_df_5.fit(df_5)
m_df_6.fit(df_6)
m_df_7.fit(df_7)
m_df_8.fit(df_8)
m_df_9.fit(df_9)
m_df_10.fit(df_10)
m_df_11.fit(df_11)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpr214xlt2/6i4kkfgo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpr214xlt2/gs26vkbh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45306', 'data', 'file=/tmp/tmpr214xlt2/6i4kkfgo.json', 'init=/tmp/tmpr214xlt2/gs26vkbh.json', 'output', 'file=/tmp/tmpr214xlt2/prophet_modelwn3s8zfp/prophet_model-20230812073102.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:31:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:31:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpr214xlt2/k3rnndt_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpr214xlt2/8iiphuf2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# ...

# %%
future = m_df_1.make_future_dataframe(periods=60)
forecast0 = m_df_1.predict(future)
future = m_df_2.make_future_dataframe(periods=60)
forecast1 = m_df_2.predict(future)
future = m_df_3.make_future_dataframe(periods=60)
forecast2 = m_df_3.predict(future)
future = m_df_4.make_future_dataframe(periods=60)
forecast3 = m_df_4.predict(future)
future = m_df_5.make_future_dataframe(periods=60)
forecast4 = m_df_5.predict(future)
future = m_df_6.make_future_dataframe(periods=60)
forecast5 = m_df_6.predict(future)
future = m_df_7.make_future_dataframe(periods=60)
forecast6 = m_df_7.predict(future)
future = m_df_8.make_future_dataframe(periods=60)
forecast7 = m_df_8.predict(future)
future = m_df_9.make_future_dataframe(periods=60)
forecast8 = m_df_9.predict(future)
future = m_df_10.make_future_dataframe(periods=60)
forecast9 = m_df_10.predict(future)
future = m_df_11.make_future_dataframe(periods=60)
forecast10 = m_df_11.predict(future)

# %%
fig1 = m_df_1.plot(forecast0)
fig2 = m_df_1.plot_components(forecast0)

# %%
forecast0 = forecast0[['ds','yhat']].tail(60)
forecast1 = forecast1[['ds','yhat']].tail(60)
forecast2 = forecast2[['ds','yhat']].tail(60)
forecast3 = forecast3[['ds','yhat']].tail(60)
forecast4 = forecast4[['ds','yhat']].tail(60)
forecast5 = forecast5[['ds','yhat']].tail(60)
forecast6 = forecast6[['ds','yhat']].tail(60)
forecast7 = forecast7[['ds','yhat']].tail(60)
forecast8 = forecast8[['ds','yhat']].tail(60)
forecast9 = forecast9[['ds','yhat']].tail(60)
forecast10 = forecast10[['ds','yhat']].tail(60)


forecast0.reset_index(drop=True, inplace=True)
forecast1.reset_index(drop=True, inplace=True)
forecast2.reset_index(drop=True, inplace=True)
forecast3.reset_index(drop=True, inplace=True)
forecast4.reset_index(drop=True, inplace=True)
forecast5.reset_index(drop=True, inplace=True)
forecast6.reset_index(drop=True, inplace=True)
forecast7.reset_index(drop=True, inplace=True)
forecast8.reset_index(drop=True, inplace=True)
forecast9.reset_index(drop=True, inplace=True)
forecast10.reset_index(drop=True, inplace=True)

# %%
forecast1.drop(['ds'],axis=1,inplace=True)
forecast2.drop(['ds'],axis=1,inplace=True)
forecast3.drop(['ds'],axis=1,inplace=True)
forecast4.drop(['ds'],axis=1,inplace=True)
forecast5.drop(['ds'],axis=1,inplace=True)
forecast6.drop(['ds'],axis=1,inplace=True)
forecast7.drop(['ds'],axis=1,inplace=True)
forecast8.drop(['ds'],axis=1,inplace=True)
forecast9.drop(['ds'],axis=1,inplace=True)
forecast10.drop(['ds'],axis=1,inplace=True)

# %%
result = pd.concat([forecast0,forecast1,forecast2,forecast3,forecast4,forecast5,forecast6,forecast7,forecast8,forecast9,forecast10],axis=1)

# %%
result
# Out:
#            ds       yhat      yhat       yhat      yhat      yhat      yhat  \
# 0  2023-04-05  -1.294608 -0.733991  -1.240147  0.274485  3.962918 -0.233226
# 1  2023-04-06  -1.734729 -1.197391  -1.729155  0.171758  4.658504 -0.390691
# 2  2023-04-07  -2.080477 -1.244705  -1.731818  0.035392  4.665569 -0.507337
# 3  2023-04-08  -2.170404 -1.167619  -1.401636 -0.085320  4.253580 -0.582965
# 4  2023-04-09  -2.169140 -0.923199  -1.198542 -0.174066  3.464572 -0.607452
# 5  2023-04-10  -2.078266 -0.755206  -1.120052 -0.250632  2.861230 -0.595158
# 6  2023-04-11  -2.163926 -0.969383  -1.208167 -0.345259  2.651926 -0.599166
# 7  2023-04-12  -2.702271 -1.415130  -1.804479 -0.504161  2.993800 -0.730436
# 8  2023-04-13  -3.350573 -2.113080  -2.512464 -0.697249  3.526029 -0.996606
# 9  2023-04-14  -3.767287 -2.140324  -2.502833 -0.795822  3.503988 -1.103886
# 10 2023-04-15  -3.711189 -1.977533  -2.031509 -0.820179  3.152043 -1.119202
# ...
